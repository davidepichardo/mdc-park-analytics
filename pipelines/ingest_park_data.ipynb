# %%
import sys
import os

# %%
import pandas as pd

# %%
df = pd.read_csv('../Park_Facility.csv')

# %%
# Out:
#                 X             Y  OBJECTID          FOLIO      ID  \
# 0   -8.947924e+06  2.947270e+06         1  3030320131910  600703
# 1   -8.948421e+06  2.957990e+06         2  3059120000010  591201
# 2   -8.943901e+06  2.953933e+06         3  3050210000141  502101
# 3   -8.944372e+06  2.967466e+06         4  3040160183390  401601
# 4   -8.933505e+06  2.976637e+06         5  3031210190550  312107
# ..            ...           ...       ...            ...     ...
# 821 -8.937118e+06  2.969578e+06     37997            NaN     NaN
# 822 -8.934490e+06  2.965340e+06     37998            NaN     NaN
# 823 -8.934712e+06  2.962627e+06     37999            NaN     NaN
# 824 -8.936739e+06  2.962621e+06     38389            NaN     NaN
# 825 -8.945144e+06  2.976086e+06     39188            NaN     NaN
#
#                               NAME                        ADDRESS  \
# 0              Roberta Hunter Park     SW 117TH AVE / SW 200TH ST
# ...
